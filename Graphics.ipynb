# %%
import pandas
import matplotlib
# %matplotlib inline

# %%
player_name= ["James", "Charles", "Sachin", "Genaro"]
age = [30, 70, 21, 16]
dataset = list(zip(player_name,age))

# %%
df = pandas.DataFrame(data = dataset, columns=["NAME", "AGE"])
df.plot()
